# %%
file = """###############
#.......#....E#
#.#.###.#.###.#
#.....#.#...#.#
#.###.#####.#.#
#.#.#.......#.#
#.#.#####.###.#
#...........#.#
###.#.#####.#.#
#...#.....#.#.#
#.#.#.###.#.#.#
#.....#...#.#.#
#.###.#.#.#.#.#
#S..#.....#...#
###############"""

# %%
map = [list(l) for l in file.strip().split("\n")]

for idx, element in enumerate(map):
    try:
        ex, ey = idx, element.index("E")
    except:
        pass
    try:
        sx, sy = idx, element.index("S")
    except:
        pass

NEIGHBOURS = [(-1,0),(1,0),(0,-1),(0,1)]
dirs = {
    0: (-1, 0),  
    1: (0, 1),   
    2: (1, 0),   
    3: (0, -1)   
}

# %%
import heapq
visited = set()
pq = []
cost = {}
sd = 1

heapq.heappush(pq, (0, sx, sy, sd))
cost[(sx, sy, sd)] = 0

while pq:
    current_cost, x, y, nd = heapq.heappop(pq)

    if (x, y, nd) in visited:
        continue
    visited.add((x, y, nd))

    if (nx, ny) == (ex, ey):
# Out:
# score is 491048
# best score so far 491048
# score is 574040
# best score so far 491048
# score is 848052
# best score so far 491048
# score is 1041064
# best score so far 491048
# score is 1026056
# best score so far 491048
# score is 1243068
# best score so far 491048
# score is 589048
# best score so far 491048
# score is 656040
# best score so far 491048
# score is 954052
# best score so far 491048
# score is 1171064
# best score so far 491048
# score is 1140056
# best score so far 491048
# score is 1381068
# best score so far 491048
# score is 223036
# best score so far 223036
# score is 290028
# best score so far 223036
# score is 492040
# best score so far 223036
# score is 637052
# best score so far 223036
# score is 630044
# best score so far 223036
# score is 799056
# best score so far 223036
# score is 223036
# best score so far 223036
# score is 290028
# best score so far 223036
# score is 444036
# best score so far 223036
# score is 589048
# best score so far 223036
# ...

# %%
exp = successful_paths[0]
dir = {
    (-1,0): "^",
    (1,0): "v",
    (0,-1): "<",
    (0,1): ">"
}
def calculate_score(path): 
    score = 0
    direction = ">"
    for idx, element in enumerate(path):
        for idx in range(len(path)-1):
            cx, cy = path[idx]
            nx, ny = path[idx +1]
            dx, dy = nx - cx, ny - cy
            new_dir = dir.get((dx,dy))
            if new_dir:
                if new_dir != direction:
                    score += 1000
                    direction = new_dir
    return score
calculate_score(exp)
